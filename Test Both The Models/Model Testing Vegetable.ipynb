# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
model=load_model('vegetable.h5')

# %%
img=image.load_img(r'C:\Users\ADMIN\Desktop\Plant Disease\Dataset Plant Disease\Veg-dataset\Veg-dataset\train_set\Potato___healthy\1a1184f8-c414-4ead-a4c4-41ae78e29a82___RS_HL 1971.JPG',target_size=(128,128))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
x=image.img_to_array(img)

# %%
x=np.expand_dims(x,axis=0)

# %%
pred=model.predict(x)
# Out:
# 1/1 [==============================] - 0s 130ms/step

# %%
pred
# Out:
# array([[0., 1., 0., 0., 0., 0., 0., 0., 0.]], dtype=float32)

# %%
list=['Pepper,_bell___Bacterial_spot','Pepper,_bell___healthy','Potato___Early_blight','Potato___healthy','Potato___Late_blight','Tomato___Bacterial_spot','Tomato___Late_blight','Tomato___Leaf_Mold','Tomato___Septoria_leaf_spot']

# %%
print(list[np.argmax(pred)])
# Out:
# Pepper,_bell___healthy
