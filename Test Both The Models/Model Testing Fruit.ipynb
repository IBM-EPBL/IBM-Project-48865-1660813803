# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
model=load_model('fruit.h5')

# %%
img=image.load_img(r'C:\Users\ADMIN\Desktop\Plant Disease\Dataset Plant Disease\fruit-dataset\fruit-dataset\test\Apple___Black_rot\1a9e869f-62b0-4588-998a-30e0d62bef59___JR_FrgE.S 2876.JPG',target_size=(128,128))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
x=image.img_to_array(img)

# %%
x=np.expand_dims(x,axis=0)

# %%
pred=model.predict(x)
# Out:
# 1/1 [==============================] - 0s 59ms/step

# %%
pred
# Out:
# array([[1., 0., 0., 0., 0., 0.]], dtype=float32)

# %%
list=['Apple___Black_rot','Apple___healthy','Corn_(maize)___healthy','Corn_(maize)___Northern_Leaf_Blight','Peach___Bacterial_spot','Peach___healthy']

# %%
print(list[np.argmax(pred)])
# Out:
# Apple___Black_rot
